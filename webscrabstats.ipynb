# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/26/Super-Lig-Stats"

# %%
data=requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select("table.stats_table")[0]

# %%
links=standings_table.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links=[l for l in links if "/squads" in l]

# %%
team_urls=[f"https://fbref.com{l}"for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/ae1e2d7d/Fenerbahce-Stats',
#  'https://fbref.com/en/squads/ecd11ca2/Galatasaray-Stats',
#  'https://fbref.com/en/squads/0f9294bd/Besiktas-Stats',
#  'https://fbref.com/en/squads/1f33fbc7/Kayserispor-Stats',
#  'https://fbref.com/en/squads/d143cf0a/Adana-Demirspor-Stats',
#  'https://fbref.com/en/squads/c8ad3091/Trabzonspor-Stats',
#  'https://fbref.com/en/squads/f622e63c/Rizespor-Stats',
#  'https://fbref.com/en/squads/d6ffefd1/Kasimpasa-Stats',
#  'https://fbref.com/en/squads/5ac76942/Antalyaspor-Stats',
#  'https://fbref.com/en/squads/c63f6c0c/Sivasspor-Stats',
#  'https://fbref.com/en/squads/076128d7/Alanyaspor-Stats',
#  'https://fbref.com/en/squads/b88463bd/Ankaragucu-Stats',
#  'https://fbref.com/en/squads/7c81865f/Gaziantep-FK-Stats',
#  'https://fbref.com/en/squads/bff39cf5/Istanbul-Basaksehir-Stats',
#  'https://fbref.com/en/squads/4b5ddee5/Hatayspor-Stats',
#  'https://fbref.com/en/squads/5700c020/Konyaspor-Stats',
#  'https://fbref.com/en/squads/bd61c555/Fatih-Karagumruk-Stats',
#  'https://fbref.com/en/squads/2f116859/Pendikspor-Stats',
#  'https://fbref.com/en/squads/77356e9e/Samsunspor-Stats',
#  'https://fbref.com/en/squads/6b2d5f93/Istanbulspor-Stats']

# %%
team_url=team_urls[0]
data=requests.get(team_url)

# %%
import pandas as pd

# %%
matches=pd.read_html(data.text, match = "Scores & Fixtures")

# %%
matches[0]
# Out:
#           Date   Time       Comp                    Round  Day Venue Result  \
# 0   2023-07-26  21:00    Conf Lg  Second qualifying round  Wed  Home      W
# 1   2023-08-01  20:30    Conf Lg  Second qualifying round  Tue  Away      W
# 2   2023-08-10  21:00    Conf Lg   Third qualifying round  Thu  Home      W
# 3   2023-08-13  21:45  Süper Lig              Matchweek 1  Sun  Home      W
# 4   2023-08-17  20:15    Conf Lg   Third qualifying round  Thu  Away      W
# 5   2023-08-21  21:00  Süper Lig              Matchweek 2  Mon  Away      W
# 6   2023-08-24  20:00    Conf Lg           Play-off round  Thu  Home      W
# 7   2023-08-31  19:00    Conf Lg           Play-off round  Thu  Away      W
# 8   2023-09-03  21:45  Süper Lig              Matchweek 4  Sun  Away      W
# 9   2023-09-17  17:00  Süper Lig              Matchweek 5  Sun  Home      W
# 10  2023-09-21  19:45    Conf Lg              Group stage  Thu  Home      W
# 11  2023-09-24  20:00  Süper Lig              Matchweek 6  Sun  Away      W
# 12  2023-09-28  20:00  Süper Lig              Matchweek 3  Thu  Home      W
# 13  2023-10-01  16:00  Süper Lig              Matchweek 7  Sun  Home      W
# 14  2023-10-05  21:00    Conf Lg              Group stage  Thu  Away      W
# 15  2023-10-08  19:00  Süper Lig              Matchweek 8  Sun  Away      W
# 16  2023-10-22  19:00  Süper Lig              Matchweek 9  Sun  Home      W
# 17  2023-10-26  19:45    Conf Lg              Group stage  Thu  Home      W
# 18  2023-10-29  19:00  Süper Lig             Matchweek 10  Sun  Away      W
# 19  2023-11-04  19:00  Süper Lig             Matchweek 11  Sat  Home      L
# 20  2023-11-09  22:00    Conf Lg              Group stage  Thu  Away      L
# 21  2023-11-12  19:00  Süper Lig             Matchweek 12  Sun  Away      D
# 22  2023-11-26  19:00  Süper Lig             Matchweek 13  Sun  Home      W
# 23  2023-11-30  21:00    Conf Lg              Group stage  Thu  Away      L
# 24  2023-12-04  20:00  Süper Lig             Matchweek 14  Mon  Home      W
# 25  2023-12-09  19:00  Süper Lig             Matchweek 15  Sat  Away      W
# 26  2023-12-14  20:45    Conf Lg              Group stage  Thu  Home      W
# 27  2023-12-20  17:00  Süper Lig             Matchweek 17  Wed  Away      W
# 28  2023-12-24  19:00  Süper Lig             Matchweek 18  Sun  Home      D
# 29  2024-01-07  16:00  Süper Lig             Matchweek 19  Sun  Away    NaN
# 30  2024-01-10  20:00  Süper Lig             Matchweek 16  Wed  Home    NaN
# 31  2024-01-14  19:00  Süper Lig             Matchweek 20  Sun  Away    NaN
# 32  2024-01-21    NaN  Süper Lig             Matchweek 21  Sun  Home    NaN
# 33  2024-01-24    NaN  Süper Lig             Matchweek 22  Wed  Away    NaN
# 34  2024-01-28    NaN  Süper Lig             Matchweek 23  Sun  Home    NaN
# 35  2024-02-04    NaN  Süper Lig             Matchweek 24  Sun  Away    NaN
# 36  2024-02-11    NaN  Süper Lig             Matchweek 25  Sun  Home    NaN
# 37  2024-02-18    NaN  Süper Lig             Matchweek 26  Sun  Away    NaN
# 38  2024-02-25    NaN  Süper Lig             Matchweek 27  Sun  Home    NaN
# 39  2024-03-03    NaN  Süper Lig             Matchweek 28  Sun  Away    NaN
# 40  2024-03-10    NaN  Süper Lig             Matchweek 29  Sun  Home    NaN
# 41  2024-03-17    NaN  Süper Lig             Matchweek 30  Sun  Away    NaN
# 42  2024-04-03    NaN  Süper Lig             Matchweek 31  Wed  Home    NaN
# 43  2024-04-07    NaN  Süper Lig             Matchweek 32  Sun  Away    NaN
# 44  2024-04-14    NaN  Süper Lig             Matchweek 33  Sun  Away    NaN
# 45  2024-04-21    NaN  Süper Lig             Matchweek 34  Sun  Home    NaN
# 46  2024-04-28    NaN  Süper Lig             Matchweek 35  Sun  Away    NaN
# 47  2024-05-05    NaN  Süper Lig             Matchweek 36  Sun  Home    NaN
# 48  2024-05-12    NaN  Süper Lig             Matchweek 37  Sun  Away    NaN
# 49  2024-05-19    NaN  Süper Lig             Matchweek 38  Sun  Home    NaN
#
#      GF   GA               Opponent   xG  xGA  Poss  Attendance      Captain  \
# 0   5.0  0.0  md FC Zimbru Chișinău  NaN  NaN   NaN     26526.0   Edin Džeko
# 1   4.0  0.0  md FC Zimbru Chișinău  NaN  NaN   NaN      7569.0  Dušan Tadić
# 2   3.0  1.0             si Maribor  NaN  NaN   NaN     33015.0   Edin Džeko
# 3   2.0  1.0           Gaziantep FK  NaN  NaN  70.0         NaN   Edin Džeko
# 4   3.0  0.0             si Maribor  NaN  NaN   NaN     10100.0    Miha Zajc
# 5   2.0  0.0             Samsunspor  NaN  NaN  60.0         NaN   Edin Džeko
# 6   5.0  1.0              nl Twente  NaN  NaN   NaN     38961.0  Dušan Tadić
# 7   1.0  0.0              nl Twente  NaN  NaN   NaN     22500.0   Edin Džeko
# 8   1.0  0.0             Ankaragücü  NaN  NaN  49.0         NaN   Edin Džeko
# 9   3.0  2.0            Antalyaspor  NaN  NaN  60.0         NaN   Edin Džeko
# 10  3.0  1.0        dk Nordsjælland  1.5  0.4  49.0         NaN  Mert Yandaş
# 11  1.0  0.0             Alanyaspor  NaN  NaN  57.0         NaN   Edin Džeko
# 12  4.0  0.0             Başakşehir  NaN  NaN  58.0         NaN   Edin Džeko
# 13  5.0  0.0               Rizespor  NaN  NaN  66.0         NaN   Edin Džeko
# 14  2.0  1.0      sk Spartak Trnava  2.4  0.8  73.0         NaN  Mert Yandaş
# 15  2.0  0.0              Kasımpaşa  NaN  NaN  62.0         NaN   Edin Džeko
# 16  4.0  2.0              Hatayspor  NaN  NaN  55.0         NaN   Edin Džeko
# 17  3.0  1.0          bg Ludogorets  1.4  0.6  62.0         NaN  Dušan Tadić
# 18  5.0  0.0             Pendikspor  NaN  NaN  62.0         NaN   Edin Džeko
# 19  2.0  3.0            Trabzonspor  NaN  NaN  65.0         NaN   Edin Džeko
# 20  0.0  2.0          bg Ludogorets  0.1  0.8  66.0         NaN  Dušan Tadić
# 21  0.0  0.0        Adana Demirspor  NaN  NaN  43.0         NaN   Edin Džeko
# 22  2.0  1.0       Fatih Karagümrük  NaN  NaN  54.0         NaN   Edin Džeko
# 23  1.0  6.0        dk Nordsjælland  0.8  3.2  62.0         NaN  Dušan Tadić
# 24  4.0  1.0              Sivasspor  NaN  NaN  49.0         NaN   Edin Džeko
# 25  3.0  1.0               Beşiktaş  NaN  NaN  54.0         NaN   Edin Džeko
# 26  4.0  0.0      sk Spartak Trnava  4.1  0.4  66.0         NaN   Edin Džeko
# 27  4.0  3.0            Kayserispor  NaN  NaN  49.0         NaN  Dušan Tadić
# 28  0.0  0.0            Galatasaray  NaN  NaN  46.0         NaN   Edin Džeko
# 29  NaN  NaN           İstanbulspor  NaN  NaN   NaN         NaN          NaN
# 30  NaN  NaN              Konyaspor  NaN  NaN   NaN         NaN          NaN
# 31  NaN  NaN           Gaziantep FK  NaN  NaN   NaN         NaN          NaN
# 32  NaN  NaN             Samsunspor  NaN  NaN   NaN         NaN          NaN
# 33  NaN  NaN             Başakşehir  NaN  NaN   NaN         NaN          NaN
# 34  NaN  NaN             Ankaragücü  NaN  NaN   NaN         NaN          NaN
# 35  NaN  NaN            Antalyaspor  NaN  NaN   NaN         NaN          NaN
# 36  NaN  NaN             Alanyaspor  NaN  NaN   NaN         NaN          NaN
# 37  NaN  NaN               Rizespor  NaN  NaN   NaN         NaN          NaN
# 38  NaN  NaN              Kasımpaşa  NaN  NaN   NaN         NaN          NaN
# 39  NaN  NaN              Hatayspor  NaN  NaN   NaN         NaN          NaN
# 40  NaN  NaN             Pendikspor  NaN  NaN   NaN         NaN          NaN
# 41  NaN  NaN            Trabzonspor  NaN  NaN   NaN         NaN          NaN
# 42  NaN  NaN        Adana Demirspor  NaN  NaN   NaN         NaN          NaN
# 43  NaN  NaN       Fatih Karagümrük  NaN  NaN   NaN         NaN          NaN
# 44  NaN  NaN              Sivasspor  NaN  NaN   NaN         NaN          NaN
# 45  NaN  NaN               Beşiktaş  NaN  NaN   NaN         NaN          NaN
# 46  NaN  NaN              Konyaspor  NaN  NaN   NaN         NaN          NaN
# 47  NaN  NaN            Kayserispor  NaN  NaN   NaN         NaN          NaN
# 48  NaN  NaN            Galatasaray  NaN  NaN   NaN         NaN          NaN
# 49  NaN  NaN           İstanbulspor  NaN  NaN   NaN         NaN          NaN
#
#    Formation             Referee  Match Report                       Notes
# 0      4-3-3     Nenad Minaković  Match Report                  Leg 1 of 2
# 1      4-3-3       Robert Harvey  Match Report  Leg 2 of 2; Fenerbahçe won
# 2      4-3-3        Robert Jones  Match Report                  Leg 1 of 2
# 3    4-1-4-1  Abdulkadir Bitigen  Match Report                         NaN
# 4      4-3-3     Fábio Veríssimo  Match Report  Leg 2 of 2; Fenerbahçe won
# 5    4-1-4-1    Volkan Bayarslan  Match Report                         NaN
# 6      4-3-3         Andy Madley  Match Report                  Leg 1 of 2
# 7      4-3-3       Fabio Maresca  Match Report  Leg 2 of 2; Fenerbahçe won
# 8    4-2-3-1      Arda Kardeşler  Match Report                         NaN
# 9    4-2-3-1    Halil Umut Meler  Match Report                         NaN
# 10   4-2-3-1         Gergő Bogár  Match Report                         NaN
# 11   4-2-3-1    Atilla Karaoğlan  Match Report                         NaN
# 12   4-2-3-1        Zorbay Küçük  Match Report                         NaN
# 13   4-2-3-1         Cihan Aydın  Match Report                         NaN
# 14     4-3-3    Sascha Stegemann  Match Report                         NaN
# 15   4-2-3-1       Mete Kalkavan  Match Report                         NaN
# 16   4-2-3-1    Volkan Bayarslan  Match Report                         NaN
# 17     4-3-3    Guillermo Cuadra  Match Report                         NaN
# 18   4-2-3-1  Abdulkadir Bitigen  Match Report                         NaN
# 19   4-2-3-1        Zorbay Küçük  Match Report                         NaN
# 20     4-3-3        Ondřej Berka  Match Report                         NaN
# 21   4-2-3-1    Halil Umut Meler  Match Report                         NaN
# 22   4-2-3-1      Arda Kardeşler  Match Report                         NaN
# 23   4-2-3-1     Jérémie Pignard  Match Report                         NaN
# 24   4-2-3-1     Bahattin Şimşek  Match Report                         NaN
# 25   4-2-3-1    Atilla Karaoğlan  Match Report                         NaN
# 26   4-2-3-1  Aleksandar Stavrev  Match Report                         NaN
# 27   4-2-3-1        Zorbay Küçük  Match Report                         NaN
# 28   4-2-3-1      Arda Kardeşler  Match Report                         NaN
# 29       NaN                 NaN  Head-to-Head                         NaN
# 30       NaN                 NaN  Head-to-Head                         NaN
# 31       NaN                 NaN  Head-to-Head                         NaN
# 32       NaN                 NaN  Head-to-Head                         NaN
# 33       NaN                 NaN  Head-to-Head                         NaN
# 34       NaN                 NaN  Head-to-Head                         NaN
# 35       NaN                 NaN  Head-to-Head                         NaN
# 36       NaN                 NaN  Head-to-Head                         NaN
# 37       NaN                 NaN  Head-to-Head                         NaN
# 38       NaN                 NaN  Head-to-Head                         NaN
# 39       NaN                 NaN  Head-to-Head                         NaN
# 40       NaN                 NaN  Head-to-Head                         NaN
# 41       NaN                 NaN  Head-to-Head                         NaN
# 42       NaN                 NaN  Head-to-Head                         NaN
# 43       NaN                 NaN  Head-to-Head                         NaN
# 44       NaN                 NaN  Head-to-Head                         NaN
# 45       NaN                 NaN  Head-to-Head                         NaN
# 46       NaN                 NaN  Head-to-Head                         NaN
# 47       NaN                 NaN  Head-to-Head                         NaN
# 48       NaN                 NaN  Head-to-Head                         NaN
# 49       NaN                 NaN  Head-to-Head                         NaN

# %%
soup=BeautifulSoup(data.text)
links=soup.find_all("a")
links=[l.get("href") for l in links]

# %%
links=[l for l in links if l and "all_comps/shooting/" in l]

# %%
links
# Out:
# ['/en/squads/ae1e2d7d/2023-2024/matchlogs/all_comps/shooting/Fenerbahce-Match-Logs-All-Competitions',
#  '/en/squads/ae1e2d7d/2023-2024/matchlogs/all_comps/shooting/Fenerbahce-Match-Logs-All-Competitions',
#  '/en/squads/ae1e2d7d/2023-2024/matchlogs/all_comps/shooting/Fenerbahce-Match-Logs-All-Competitions',
#  '/en/squads/ae1e2d7d/2023-2024/matchlogs/all_comps/shooting/Fenerbahce-Match-Logs-All-Competitions']

# %%
data=requests.get(f"https://fbref.com/{links[0]}")

# %%
shooting = pd.read_html(data.text,match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Fenerbahçe                                                               \
#             Date   Time       Comp                    Round  Day Venue Result
# 0     2023-07-26  21:00    Conf Lg  Second qualifying round  Wed  Home      W
# 1     2023-08-01  20:30    Conf Lg  Second qualifying round  Tue  Away      W
# 2     2023-08-10  21:00    Conf Lg   Third qualifying round  Thu  Home      W
# 3     2023-08-13  21:45  Süper Lig              Matchweek 1  Sun  Home      W
# 4     2023-08-17  20:15    Conf Lg   Third qualifying round  Thu  Away      W
#
#                                     ... Standard              Expected       \
#     GF   GA               Opponent  ...     Dist  FK PK PKatt       xG npxG
# 0  5.0  0.0  md FC Zimbru Chișinău  ...      NaN NaN  0     0      NaN  NaN
# 1  4.0  0.0  md FC Zimbru Chișinău  ...      NaN NaN  0     0      NaN  NaN
# 2  3.0  1.0             si Maribor  ...      NaN NaN  1     1      NaN  NaN
# 3  2.0  1.0           Gaziantep FK  ...      NaN NaN  0     1      NaN  NaN
# 4  3.0  0.0             si Maribor  ...      NaN NaN  0     0      NaN  NaN
#
#                        Unnamed: 25_level_0
#   npxG/Sh G-xG np:G-xG        Match Report
# 0     NaN  NaN     NaN        Match Report
# 1     NaN  NaN     NaN        Match Report
# 2     NaN  NaN     NaN        Match Report
# 3     NaN  NaN     NaN        Match Report
# 4     NaN  NaN     NaN        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time       Comp                    Round  Day Venue Result  \
# 0  2023-07-26  21:00    Conf Lg  Second qualifying round  Wed  Home      W
# 1  2023-08-01  20:30    Conf Lg  Second qualifying round  Tue  Away      W
# 2  2023-08-10  21:00    Conf Lg   Third qualifying round  Thu  Home      W
# 3  2023-08-13  21:45  Süper Lig              Matchweek 1  Sun  Home      W
# 4  2023-08-17  20:15    Conf Lg   Third qualifying round  Thu  Away      W
#
#     GF   GA               Opponent  ...  Dist  FK  PK  PKatt  xG  npxG  \
# 0  5.0  0.0  md FC Zimbru Chișinău  ...   NaN NaN   0      0 NaN   NaN
# 1  4.0  0.0  md FC Zimbru Chișinău  ...   NaN NaN   0      0 NaN   NaN
# 2  3.0  1.0             si Maribor  ...   NaN NaN   1      1 NaN   NaN
# 3  2.0  1.0           Gaziantep FK  ...   NaN NaN   0      1 NaN   NaN
# 4  3.0  0.0             si Maribor  ...   NaN NaN   0      0 NaN   NaN
#
#    npxG/Sh  G-xG  np:G-xG  Match Report
# 0      NaN   NaN      NaN  Match Report
# 1      NaN   NaN      NaN  Match Report
# 2      NaN   NaN      NaN  Match Report
# 3      NaN   NaN      NaN  Match Report
# 4      NaN   NaN      NaN  Match Report
#
# [5 rows x 26 columns]

# %%
team_data = matches[0].merge(shooting[["Date","Sh","SoT","Dist","FK","PK","PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time       Comp                    Round  Day Venue Result  \
# 0  2023-07-26  21:00    Conf Lg  Second qualifying round  Wed  Home      W
# 1  2023-08-01  20:30    Conf Lg  Second qualifying round  Tue  Away      W
# 2  2023-08-10  21:00    Conf Lg   Third qualifying round  Thu  Home      W
# 3  2023-08-13  21:45  Süper Lig              Matchweek 1  Sun  Home      W
# 4  2023-08-17  20:15    Conf Lg   Third qualifying round  Thu  Away      W
#
#     GF   GA               Opponent  ...  Formation             Referee  \
# 0  5.0  0.0  md FC Zimbru Chișinău  ...      4-3-3     Nenad Minaković
# 1  4.0  0.0  md FC Zimbru Chișinău  ...      4-3-3       Robert Harvey
# 2  3.0  1.0             si Maribor  ...      4-3-3        Robert Jones
# 3  2.0  1.0           Gaziantep FK  ...    4-1-4-1  Abdulkadir Bitigen
# 4  3.0  0.0             si Maribor  ...      4-3-3     Fábio Veríssimo
#
#    Match Report                       Notes    Sh  SoT Dist  FK PK  PKatt
# 0  Match Report                  Leg 1 of 2   NaN  NaN  NaN NaN  0      0
# 1  Match Report  Leg 2 of 2; Fenerbahçe won   NaN  NaN  NaN NaN  0      0
# 2  Match Report                  Leg 1 of 2   NaN  NaN  NaN NaN  1      1
# 3  Match Report                         NaN  20.0  5.0  NaN NaN  0      1
# 4  Match Report  Leg 2 of 2; Fenerbahçe won   NaN  NaN  NaN NaN  0      0
#
# [5 rows x 25 columns]
